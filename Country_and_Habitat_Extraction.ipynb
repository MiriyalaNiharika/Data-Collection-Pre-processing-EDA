# %%
#Importing required libraries
import pycountry
import pandas as pd
import numpy as np
import wikipedia

# %%
birds_df = pd.read_excel('Birds_Dataset_after_Data-preprocessing.xlsx', sheet_name = 'Sheet1')
birds_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1               Name     Conservation status  \
# 0           0             0   Giant honeyeater                     NaN
# 1           1             1  Giant hummingbird          Least Concern
# 2           2             2         Giant ibis  Critically Endangered
#
#     Kingdom    Phylum Class           Order             Family  \
# 0  Animalia  Chordata  Aves   Passeriformes       Meliphagidae
# 1  Animalia  Chordata  Aves     Apodiformes        Trochilidae
# 2  Animalia  Chordata  Aves  Pelecaniformes  Threskiornithidae
#
#                         Genus            Species  \
# 0                   Gymnomyza  G. brunneirostris
# 1     PatagonaG.R. Gray, 1840           P. gigas
# 2  ThaumatibisElliot, 1877[2]        T. gigantea
#
#                           Binomial Name  \
# 0  Gymnomyza brunneirostris(Mayr, 1932)
# 1        Patagona gigas(Vieillot, 1824)
# 2  Thaumatibis gigantea(Oustalet, 1877)
#
#                                              Summary  \
# ...

# %% [markdown]
# Also scraped the below two attributes by using pre-defined lists:
#
# Country – pycountry package has a list of all the countries in this world. If any of those countries are mentioned in the description of the birds, then it is scraped
# Habitat – Custom created a list of all the bird habitats. If any of those habitats are mentioned in the description of the birds, then it is scraped

# %%
birds_df['Countries'] = np.NaN
birds_df['Habitat'] = np.NaN

# %%
def findCountry(data):
    countries = sorted([country.name for country in pycountry.countries] , key=lambda x: -len(x))
    for country in countries:
        if country.lower() in data.lower():
            return country
    return None

# %%
#habitat
habitats_list = ['forest', 'forests', 'woods', 'woods', 'woodland', 'woodlands', 'bog', 'bogs', 'fen', 'fens', 'marsh', 'marshes', 'swamp', 'swamps', 'wetland', 'grasslands', 'prairie', 'scrubs','shrubs', 'backyards']

# %%
def findHabitat(data):
    for habitat in habitats_list:
        if habitat in data.lower():
            return habitat
    return None

# %%
for i in range(0, len(birds_df)):
    name = birds_df.Name[i]
    summary = wikipedia.summary(name)
    birds_df.Countries[i] = findCountry(summary)
    birds_df.Habitat[i] = findHabitat(summary)
# Out:
# <ipython-input-13-63f18dc35a6d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   birds_df.Countries[i] = findCountry(summary)
# C:\Users\Niharika\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# <ipython-input-13-63f18dc35a6d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
birds_df.head(20)
# Out:
#    Unnamed: 0  Unnamed: 0.1               Name     Conservation status  \
# 0           0             0   Giant honeyeater                     NaN
# 1           1             1  Giant hummingbird          Least Concern
# 2           2             2         Giant ibis  Critically Endangered
#
#     Kingdom    Phylum Class           Order             Family  \
# 0  Animalia  Chordata  Aves   Passeriformes       Meliphagidae
# 1  Animalia  Chordata  Aves     Apodiformes        Trochilidae
# 2  Animalia  Chordata  Aves  Pelecaniformes  Threskiornithidae
#
#                         Genus            Species  \
# 0                   Gymnomyza  G. brunneirostris
# 1     PatagonaG.R. Gray, 1840           P. gigas
# 2  ThaumatibisElliot, 1877[2]        T. gigantea
#
#                           Binomial Name  \
# 0  Gymnomyza brunneirostris(Mayr, 1932)
# 1        Patagona gigas(Vieillot, 1824)
# 2  Thaumatibis gigantea(Oustalet, 1877)
#
#                                              Summary  \
# ...

# %%
#Exporting data to Excel
#Give File name here
file_name = 'bird_after_adding_Country&Habitat.xlsx'
  
# writing to excel
birds_df.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.
